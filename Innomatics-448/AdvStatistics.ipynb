# %%
import pandas as pd

# %%
uber_df = pd.read_csv("My_Uber_Drives_2016.csv")
uber_df.drop(1155,axis=0,inplace=True)

# %%
uber_df["PURPOSE*"].unique().shape
# Out:
# (11,)

# %%
probability_for_uniform_distrubution = 1/11

# %%
((((uber_df["PURPOSE*"].value_counts()/uber_df.shape[0])==probability_for_uniform_distrubution).sum())/11)*100
# Out:
# 0.0

# %%
mean_ = uber_df["MILES*"].mean()

# %%
mode_ = uber_df["MILES*"].mode()

# %%
mode_
# Out:
# 0    9.9
# Name: MILES*, dtype: float64

# %%
mean_
# Out:
# 10.566839826839827

# %%
std_ = uber_df["MILES*"].std()

# %%
skewness = (mean_-mode_)/std_

# %%
skewness
# Out:
# 0    0.030902
# Name: MILES*, dtype: float64

# %%
uber_df["MILES*"].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
titanic_df = pd.read_csv("../../Downloads/Titanic-Dataset.xls")

# %%
age_mean = titanic_df["Age"].mean()
age_mode = titanic_df["Age"].mode()
age_std = titanic_df["Age"].std()

# %%
age_skewness = (age_mean-age_mode)/age_std

# %%
age_skewness
# Out:
# 0    0.392326
# Name: Age, dtype: float64

# %%
titanic_df["Age"].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
uber_df["MILES*"].median()
# Out:
# 6.0

# %%
mean_
# Out:
# 10.566839826839827

# %%
mode_
# Out:
# 0    9.9
# Name: MILES*, dtype: float64

# %%
#(mean_-mode) = 3 * (mean_ - median_)
# 3 * median_ = 3 * mean_ - mean_ + mode_
median_ = 2/3 * mean_ + 1/3 * mode_

# %%
median_
# Out:
# 0    10.34456
# Name: MILES*, dtype: float64

# %%
fare_mean = titanic_df["Fare"].mean()
fare_mode = titanic_df["Fare"].mode()
fare_std = titanic_df["Fare"].std()
fare_skewness = (fare_mean-fare_mode)/fare_std
fare_skewness
# Out:
# 0    0.486064
# Name: Fare, dtype: float64

# %%
titanic_df["Fare"].plot.kde()
# Out:
# <Axes: ylabel='Density'>
