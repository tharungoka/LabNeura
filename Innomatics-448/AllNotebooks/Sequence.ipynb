# %% [markdown]
# # String Definitions

# %%
var = 'Innomatics'

# %%
var1 = "Innomatics"

# %%
var2 = 'He said, "Sun rises in the east"'

# %%
var3 = '''He said, "I'm hungry"'''

# %%
var4 = "He said, \"Sun rises in the east\""

# %%
print(var)
print(var1)
print(var2)
print(var3)
print(var4)
# Out:
# Innomatics
# Innomatics
# He said, "Sun rises in the east"
# He said, "I'm hungry"
# He said, "Sun rises in the east"

# %% [markdown]
# # Escape Character
# - escaping immediate next character.
# - New line ==> \n is a new line character.
# - Tab ===> \t is a tab character

# %%
ord("\n"), ord("\t")
# Out:
# (10, 9)

# %%
print("Hello World!\n")
# Out:
# Hello World!

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
var5 = "Hello"
var6 = "Hello"

# %%
id(var5), id(var6)
# Out:
# (4426054256, 4426054256)

# %%
var7 = "Hello World"
var8 = "Hello World"

# %%
id(var7), id(var8)
# Out:
# (4426083184, 4426083120)

# %%
import sys

# %%
var9 = sys.intern("Hello World")
var10 = sys.intern("Hello World")

# %%
id(var9), id(var10)
# Out:
# (4426105136, 4426105136)

# %%
var11 = f"var9 = {var9}, var10 = {var10}" # fstrings

# %%
print(var11)
# Out:
# var9 = Hello World, var10 = Hello World

# %%
help(str.__add__)
# Out:
# Help on wrapper_descriptor:
#
# __add__(self, value, /)
#     Return self+value.

# %%
def sum(a,b):
    """
    Sum is a arithmetic function.

    Arguments: 
        - a
        - b
    Returns:
        - Sum of a,b
    """
    return a+b

# %%
help(sum)
# Out:
# Help on function sum in module __main__:
#
# sum(a, b)
#     Sum is a arithmetic function.
#
#     Arguments:
#         - a
#         - b
#     Returns:
#         - Sum of a,b

# %% [markdown]
# # Comments in Python
# - Comments are informative statements in codebase.
# - Single line comments --> writing only one line comment.
# - Multiple line comments --> writing mutiple lines of comments using single syntax

# %%
pi = 3.141 #PI is constant

# %%
# comment1
# comment2

# %%
name = "Innomatics"

# %%
name[0]
# Out:
# 'I'

# %%
name[-1]
# Out:
# 's'

# %%
name[10] # Runtime Error #Index out of bound. / out of range
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 name[10] # Runtime Error #Index out of bound. / out of range
#
# IndexError: string index out of range

# %%
name[-10]
# Out:
# 'I'

# %%
len(name) #Iterator
# Out:
# 10

# %%
name[4:]
# Out:
# 'matics'

# %%
name[-4:]
# Out:
# 'tics'

# %%
name[-4:-1]
# Out:
# 'tic'

# %%
name[1:4]
# Out:
# 'nno'

# %%
name[-1:-1]
# Out:
# ''

# %%
name[4:0]
# Out:
# ''

# %% [markdown]
# # List

# %%
l1 = [1,2,3]

# %%
l2 = [2,3,4]

# %%
l1 + l2
# Out:
# [1, 2, 3, 2, 3, 4]
