# %% [markdown]
# # Set Definitions

# %%
s = set()

# %%
s1 = {1,2,3}

# %%
s2 = {2,3,4}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4}

# %%
s1.intersection(s2)
# Out:
# {2, 3}

# %%
s1.difference(s2)
# Out:
# {1}

# %%
s1.symmetric_difference(s2)
# Out:
# {1, 4}
