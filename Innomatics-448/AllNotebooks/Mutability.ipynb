# %%
name = "Data Science" # String Data Structure

# %%
students = ["Sanjay", "Srinivas", "Sowmya", "Sanjana", "Nikshith", "Tharun"] # List Data Structure

# %%
record = (1, "Rajesh", 28, 448, "Python") # Tuple Data Structure

# %%
name[4] = "_"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 name[4] = "_"
#
# TypeError: 'str' object does not support item assignment

# %%
name.replace(" ","_")
# Out:
# 'Data_Science'

# %%
name
# Out:
# 'Data Science'

# %%
name = name.replace(" ", "_")

# %%
name
# Out:
# 'Data_Science'

# %%
students[3]
# Out:
# 'Sanjana'

# %%
students[3] = "Aditya"

# %%
record
# Out:
# (1, 'Rajesh', 28, 448, 'Python')

# %%
record[1] = "Tharun"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 record[1] = "Tharun"
#
# TypeError: 'tuple' object does not support item assignment

# %%
record1 = (1, "Rajesh", [9123423452,3445234523])
