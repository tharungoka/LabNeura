# %%
100
# Out:
# 100

# %%
print(100)
# Out:
# 100

# %%
a = 3007654876586

# %%
c = a

# %%
d = a

# %%
b = 500

# %%
import sys

# %%
sys.getrefcount(a)
# Out:
# 4

# %%
del a

# %%
c
# Out:
# 3007654876586

# %%
sys.getrefcount(3007654876586)
# Out:
# 3

# %%
$gt = 15
# Out:
#   Cell In[20], line 1
#     $gt = 15
#     ^
# SyntaxError: invalid syntax

# %%
g$t = 15
# Out:
#   Cell In[21], line 1
#     g$t = 15
#      ^
# SyntaxError: invalid syntax

# %%
area = 100

# %%
area_ = area

# %%
_area = area

# %%
a = True

# %%
type(a)
# Out:
# bool

# %% [markdown]
# # Arithmetic Operations
# - Add
# - Sub
# - Multiple
#     - Power
# - Division (True Division)
#     - Floor Division
#     - Modulo

# %% [markdown]
# # Integers

# %%
a = 100
b = 100

# %%
a + b # a.__add__(b)
# Out:
# 200

# %%
a.__add__(b)
# Out:
# 200

# %%
type(a)
# Out:
# int

# %%
dir(a)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
# ...

# %%
t = True

# %%
a - b
# Out:
# 0

# %%
a * b
# Out:
# 10000

# %%
a / b
# Out:
# 1.0

# %%
c = 2
d = 5

# %%
c/d
# Out:
# 0.4

# %%
a // b
# Out:
# 1

# %%
a % b
# Out:
# 0

# %% [markdown]
# # Floating Point Numbers

# %%
a = 2.0
b = 3.9
a+b
# Out:
# 5.9

# %%
c = 2

# %%
type(a), type(c)
# Out:
# (float, int)

# %%
a = 2.2
b = 1.1

# %%
a+b
# Out:
# 3.3000000000000003

# %% [markdown]
# # Strings

# %%
name = "Innomatics"

# %%
var = "Data Science"

# %%
var1 = 2

# %%
name + var
# Out:
# 'InnomaticsData Science'

# %%
name + var1 # name.__add__(var1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 name + var1
#
# TypeError: can only concatenate str (not "int") to str

# %%
name - var1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 name - var1
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %% [markdown]
# # Booleans

# %%
a = True
b = False

# %%
type(a), type(b)
# Out:
# (bool, bool)

# %%
a + b
# Out:
# 1

# %% [markdown]
# # Calling Object and Arguments for Addition

# %%
p = 300

# %%
z = None

# %%
p+z
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 p+z
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'

# %%
x = "Innomatics"

# %%
y = None

# %%
x+y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 x+y
#
# TypeError: can only concatenate str (not "NoneType") to str

# %% [markdown]
# # Logical Operators

# %%
5 and 7
# Out:
# 7

# %%
5 or 7
# Out:
# 5

# %%
# Out:
# 5

# %% [markdown]
# dir(str)

# %%
help(str.__mul__)
# Out:
# Help on wrapper_descriptor:
#
# __mul__(self, value, /)
#     Return self*value.

# %%
str(1) - str(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 str(1) - str(1)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
str(1) * int(1)
# Out:
# '1'

# %%
int(1) * str(1)
# Out:
# '1'

# %%
st = "back"

# %%
help(str.__mod__)
# Out:
# Help on wrapper_descriptor:
#
# __mod__(self, value, /)
#     Return self%value.

# %%
st % None
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 st % None
#
# TypeError: not all arguments converted during string formatting

# %% [markdown]
# # Other operators
# - < __lt__
# - <= __le__
# - "> __gt__
# - ">= __ge__
# - != __ne__

# %%
print(1 > 2)
print(2<3)
print(1.1>0.1)
print(1>=1)
print(False>True)
print(True!=False)
print("Hi">"Hello")
print("Hello"!="Hello")
# Out:
# False
# True
# True
# True
# False
# True
# True
# False

# %%
x = "Hello"
y = "Hello"

# %%
x == y
# Out:
# True

# %%
id(x), id(y)
# Out:
# (4427289840, 4427289840)

# %%
x is y
# Out:
# True

# %%
#Comparision -> O(n) # number of chjaracters
#identity operator --> O(1) # only one comparision.

# %% [markdown]
# # String Multiplication
# # Boolean Floor Division

# %%
"string" * 3
# Out:
# 'stringstringstring'

# %%
a = True
b = 10

# %%
a // b
# Out:
# 0

# %%
True // -2
# Out:
# -1

# %%
False // -2
# Out:
# 0
