# %%
file = open("names.txt") # FILE object

# %%
file.close()

# %%
with open("names.txt") as file:
    content = file.read()

# %%
content
# Out:
# 'Innomatics\nTharun Kumar\nSainadh\nRamadevi\nSrinivas\nRamu\nRaju\nRajesh\nPrashant\nManoj\nChandrika\nGokul\nSubbu\nMirza'

# %%
content = file.read()

# %%
content_1 = file.readlines()

# %%
content_1
# Out:
# ['Innomatics\n',
#  'Tharun Kumar\n',
#  'Sainadh\n',
#  'Ramadevi\n',
#  'Srinivas\n',
#  'Ramu\n',
#  'Raju\n',
#  'Rajesh\n',
#  'Prashant\n',
#  'Manoj\n',
#  'Chandrika\n',
#  'Gokul\n',
#  'Subbu\n',
#  'Mirza']

# %%
name = "Innomatics      "

# %%
name.rstrip()
# Out:
# 'Innomatics'

# %%
name_1 = "Innomatics\n"

# %%
name_1.rstrip()
# Out:
# 'Innomatics'

# %%
type(content)
# Out:
# str

# %%
content.splitlines()
# Out:
# ['Innomatics',
#  'Tharun Kumar',
#  'Sainadh',
#  'Ramadevi',
#  'Srinivas',
#  'Ramu',
#  'Raju',
#  'Rajesh',
#  'Prashant',
#  'Manoj',
#  'Chandrika',
#  'Gokul',
#  'Subbu',
#  'Mirza']

# %%
content_1 = file.read()

# %%
content_1
# Out:
# ''

# %%
name_2 = "  Innomatics   "

# %%
name_2.strip()
# Out:
# 'Innomatics'

# %%
var = "Rajesh has a dog, the name of the dog is Jimmy"

# %%
var.replace("Jimmy","Dummy")
# Out:
# 'Rajesh has a dog, the name of the dog is Dummy'

# %%
var
# Out:
# 'Rajesh has a dog, the name of the dog is Jimmy'

# %%
var.split()
# Out:
# ['Rajesh',
#  'has',
#  'a',
#  'dog,',
#  'the',
#  'name',
#  'of',
#  'the',
#  'dog',
#  'is',
#  'Jimmy']

# %%
var.split(" ")
# Out:
# ['Rajesh',
#  'has',
#  'a',
#  'dog,',
#  'the',
#  'name',
#  'of',
#  'the',
#  'dog',
#  'is',
#  'Jimmy']

# %%
# Given absolute path find the filename??
# Ex: /root/users/tkumar/file.txt

# %%
var = "/root/users/tkumar/file.txt"

# %%
var.split("t")
# Out:
# ['/roo', '/users/', 'kumar/file.', 'x', '']

# %%
var.split("/")
# Out:
# ['', 'root', 'users', 'tkumar', 'file.txt']

# %%
"/".join(var.split("/"))
# Out:
# '/root/users/tkumar/file.txt'

# %%
# Given an absolute path find the unique name using the path?

# %%
var.replace("/","_")
# Out:
# '_root_users_tkumar_file.txt'

# %%
## Membership Operator --> in

# %%
var
# Out:
# '/root/users/tkumar/file.txt'

# %%
"tg" in var #Sliding search
# Out:
# False
