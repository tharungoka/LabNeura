# %%
100
# Out:
# 100

# %%
a = 100

# %%
id(100)
# Out:
# 4334465288

# %%
id(100)
# Out:
# 4334465288

# %%
a
# Out:
# 100

# %%
print(a)
# Out:
# 100

# %%
type(a)
# Out:
# int

# %%
b = 9.8

# %%
type(b)
# Out:
# float

# %%
c = 'Innomatics'

# %%
type(c)
# Out:
# str

# %%
d = 'd'

# %%
type(d)
# Out:
# str

# %%
e = ''

# %%
type(e)
# Out:
# str

# %%
f = True

# %%
g = False

# %%
type(f)
# Out:
# bool

# %%
type(g)
# Out:
# bool

# %%
h = None

# %%
try

# %%
id(None)
# Out:
# 4320940584

# %%
g = None

# %%
id(g)
# Out:
# 4320940584

# %%
h = None
i = None
k = None

# %%
id(h),id(i),id(k)
# Out:
# (4320940584, 4320940584, 4320940584)

# %%
a = 100
b = 100
c = 100

# %%
id(a), id(b), id(c)
# Out:
# (4321865992, 4321865992, 4321865992)

# %%
a = 300

# %%
b = 300

# %%
id(a)
# Out:
# 4354900656

# %%
id(b)
# Out:
# 4354900624

# %% [markdown]
# a = 100
# b = 100
# c = 100

# %%
ord('a')
# Out:
# 97

# %%
ord('A')
# Out:
# 65
